# %% [markdown]
# ## Covid-19 Analysis and Visualizations

# %% [markdown]
# ### Files to work with:
# ##### Source 1 data in output_data/data_source_1
# ##### Source 2 data in output_data/data_source_2
# ##### Source 3 data in output_data/data_source_3
# ##### Population data in output_data/state_pop_df
# ##### State date data in output_data/state_df
#
#
#
# ### First Objective: Determine how the three datasets compare and see if they reveal either consistencies or inconsistencies.
#
# To answer this aspect of our analysis, we produced a line plot using each of the three different data sources. The line plots examine date versus total Covid-19 cases in the 6 states. We then compared the plots to see if there were any descrepancies in the data.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import scipy.stats as st
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Load the csv data files
data_source_1 = 'output_data/data_source_1.csv'
data_source_2 = 'output_data/data_source_2.csv'
data_source_3 = 'output_data/data_source_3.csv'

# Read the Covid-19 data and study the results
data_1 = pd.read_csv(data_source_1)
data_2 = pd.read_csv(data_source_2)
data_3 = pd.read_csv(data_source_3)

# Change the date to data/time format for plotting
data_1['date'] = pd.to_datetime(data_1['date'])
data_2['date'] = pd.to_datetime(data_2['date'])
data_3['date'] = pd.to_datetime(data_3['date'])

print(data_1.dtypes)
# Out:
# state                     object
# date              datetime64[ns]
# positive cases             int64
# negative cases             int64
# dtype: object

# %% [markdown]
# Data Source 1:

# %%
# Preview first data source
data_1
# Out:
#            state       date  positive cases  negative cases
# 0    Connecticut 2020-03-08               1              29
# 1    Connecticut 2020-03-09               1              46
# 2    Connecticut 2020-03-10               2              54
# 3    Connecticut 2020-03-11               3              71
# 4    Connecticut 2020-03-12               6              89
# ..           ...        ...             ...             ...
# 776        Texas 2020-07-13          264313         2275812
# 777        Texas 2020-07-14          275058         2323622
# 778        Texas 2020-07-15          282365         2359834
# 779        Texas 2020-07-16          292656         2407199
# 780        Texas 2020-07-17          307572         2459749
#
# [781 rows x 4 columns]

# %%
# Generate a line plot of date versus positive cases for each of the 6 different states 
florida1 = data_1.loc[data_1['state'] == 'Florida']
georgia1 = data_1.loc[data_1['state'] == 'Georgia']
texas1 = data_1.loc[data_1['state'] == 'Texas']
newyork1 = data_1.loc[data_1['state'] == 'New York']
newjersey1 = data_1.loc[data_1['state'] == 'New Jersey']
connecticut1 = data_1.loc[data_1['state'] == 'Connecticut']

# Plot each state separately on same graph
plt.plot(florida1['date'], florida1['positive cases'], color='green', label='Florida')
plt.plot(georgia1['date'], georgia1['positive cases'], color='blue', label='Georgia')
plt.plot(texas1['date'], texas1['positive cases'], color='darkorange', label='Texas')
plt.plot(newyork1['date'], newyork1['positive cases'], color='blueviolet', label='New York')
plt.plot(newjersey1['date'], newjersey1['positive cases'], color='red', label='New Jersey')
plt.plot(connecticut1['date'], connecticut1['positive cases'], color='tan', label='Connecticut')

# Define labels of plot
plt.title('Data Source 1, Covid-19 Cases for 6 Select States')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.legend(loc="best")

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/DataSource1.png')

plt.show()

# %% [markdown]
# Data Source 2:

# %%
# Preview second data source
data_2
# Out:
#            state       date  positive cases
# 0    Connecticut 2020-03-08               1
# 1    Connecticut 2020-03-09               2
# 2    Connecticut 2020-03-10               2
# 3    Connecticut 2020-03-11               3
# 4    Connecticut 2020-03-12               6
# ..           ...        ...             ...
# 848        Texas 2020-07-15          296478
# 849        Texas 2020-07-16          311516
# 850        Texas 2020-07-17          321242
# 851        Texas 2020-07-18          330059
# 852        Texas 2020-07-19          338036
#
# [853 rows x 3 columns]

# %%
# Generate a line plot of date versus positive cases for each of the 6 different states 
florida2 = data_2.loc[data_2['state'] == 'Florida']
georgia2 = data_2.loc[data_2['state'] == 'Georgia']
texas2 = data_2.loc[data_2['state'] == 'Texas']
newyork2 = data_2.loc[data_2['state'] == 'New York']
newjersey2 = data_2.loc[data_2['state'] == 'New Jersey']
connecticut2 = data_2.loc[data_2['state'] == 'Connecticut']

# Plot each state separately on same graph
plt.plot(florida2['date'], florida2['positive cases'], color='green', label='Florida')
plt.plot(georgia2['date'], georgia2['positive cases'], color='blue', label='Georgia')
plt.plot(texas2['date'], texas2['positive cases'], color='darkorange', label='Texas')
plt.plot(newyork2['date'], newyork2['positive cases'], color='blueviolet', label='New York')
plt.plot(newjersey2['date'], newjersey2['positive cases'], color='red', label='New Jersey')
plt.plot(connecticut2['date'], connecticut2['positive cases'], color='tan', label='Connecticut')

# Define labels of plot
plt.title('Data Source 2, Covid-19 Cases for 6 Select States')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.legend(loc="best")

# Save the line plot to a PNG file
plt.savefig('output_data/DataSource2.png')

plt.show()

# %% [markdown]
# Data Source 3:

# %%
# Preview the third data source
data_3
# Out:
#            state       date  positive cases
# 0    Connecticut 2020-03-08               1
# 1    Connecticut 2020-03-09               2
# 2    Connecticut 2020-03-10               2
# 3    Connecticut 2020-03-11               3
# 4    Connecticut 2020-03-12               6
# ..           ...        ...             ...
# 818        Texas 2020-07-13          273732
# 819        Texas 2020-07-14          284638
# 820        Texas 2020-07-15          296478
# 821        Texas 2020-07-16          311516
# 822        Texas 2020-07-17          321254
#
# [823 rows x 3 columns]

# %%
# Generate a line plot of date versus positive cases for each of the 6 different states 
florida3 = data_3.loc[data_3['state'] == 'Florida']
georgia3 = data_3.loc[data_3['state'] == 'Georgia']
texas3 = data_3.loc[data_3['state'] == 'Texas']
newyork3 = data_3.loc[data_3['state'] == 'New York']
newjersey3 = data_3.loc[data_3['state'] == 'New Jersey']
connecticut3 = data_3.loc[data_3['state'] == 'Connecticut']

# Plot each state separately on same graph
plt.plot(florida3['date'], florida3['positive cases'], color='green', label='Florida')
plt.plot(georgia3['date'], georgia3['positive cases'], color='blue', label='Georgia')
plt.plot(texas3['date'], texas3['positive cases'], color='darkorange', label='Texas')
plt.plot(newyork3['date'], newyork3['positive cases'], color='blueviolet', label='New York')
plt.plot(newjersey3['date'], newjersey3['positive cases'], color='red', label='New Jersey')
plt.plot(connecticut3['date'], connecticut3['positive cases'], color='tan', label='Connecticut')

# Define labels of plot
plt.title('Data Source 3, Covid-19 Cases for 6 Select States')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.legend(loc="best")

# Save the line plot to a PNG file
plt.savefig('output_data/DataSource3.png')

plt.show()

# %% [markdown]
# The 3 data sources compared:

# %%
# Plot each state separately on same graph
plt.plot(florida1['date'], florida1['positive cases'], color='green', label='Florida')
plt.plot(georgia1['date'], georgia1['positive cases'], color='blue', label='Georgia')
plt.plot(texas1['date'], texas1['positive cases'], color='darkorange', label='Texas')
plt.plot(newyork1['date'], newyork1['positive cases'], color='blueviolet', label='New York')
plt.plot(newjersey1['date'], newjersey1['positive cases'], color='red', label='New Jersey')
plt.plot(connecticut1['date'], connecticut1['positive cases'], color='tan', label='Connecticut')
plt.plot(florida2['date'], florida2['positive cases'], color='green')
plt.plot(georgia2['date'], georgia2['positive cases'], color='blue')
plt.plot(texas2['date'], texas2['positive cases'], color='darkorange')
plt.plot(newyork2['date'], newyork2['positive cases'], color='blueviolet')
plt.plot(newjersey2['date'], newjersey2['positive cases'], color='red')
plt.plot(connecticut2['date'], connecticut2['positive cases'], color='tan')
plt.plot(florida3['date'], florida3['positive cases'], color='green')
plt.plot(georgia3['date'], georgia3['positive cases'], color='blue')
plt.plot(texas3['date'], texas3['positive cases'], color='darkorange')
plt.plot(newyork3['date'], newyork3['positive cases'], color='blueviolet')
plt.plot(newjersey3['date'], newjersey3['positive cases'], color='red')
plt.plot(connecticut3['date'], connecticut3['positive cases'], color='tan')

# Define labels of plot
plt.title('3 Data Sources Overlaid Showing Covid-19 Cases for 6 Select States')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.legend(loc="best")

# Save the line plot to a PNG file
plt.savefig('output_data/CombinedDataSource.png')

plt.show()

# %% [markdown]
# #### We concluded that there were only minimal inconsistencies in the three data sources, as indicated by the nearly identical appearances of the 3 line graphs when overlaid upon each other.

# %% [markdown]
# ### Second Objective: What % of population was tested and how much does testing vary from state to state? Does the testing percentages correlate to Covid-19 count?
#
# To examine these aspects of the data, we compared the state populations in a histogram and then plotted the percentage of each states population that was tested over time.
#
# We then ran a linear regression to see how closely the average testing percentage of each state correlates to the average daily Covid-19 count.

# %%
# Load and read the state population csv file
state_population = pd.read_csv('output_data/state_pop_df.csv')
state_population
# Out:
#          state  population
# 0  Connecticut     3581504
# 1      Florida    20598139
# 2      Georgia    10297484
# 3   New Jersey     8881845
# 4     New York    19618453
# 5        Texas    27885195

# %%
# Create bar graph of comparative state population
plt.bar(state_population['state'], state_population['population'], 
        color=['tan', 'green', 'blue', 'red', 'blueviolet', 'darkorange'])
plt.title('Comparitive State Population')
plt.xlabel('State')
plt.ylabel('Population (10 mil)')

# Save the bar graph to a PNG file
plt.savefig('output_data/StatePopulation.png')

plt.show()

# %%
# Run calculations for bar graph variables
florida_tested = florida1['positive cases'] + florida1['negative cases']
florida_population = state_population.iloc[1]['population']
florida_percentage = (florida_tested / florida_population) * 100
florida_avg = florida_percentage.mean()

# Set title, axis labels, y-axis limits 
plt.bar(florida1['date'], florida_percentage, color='green')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Florida Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/FloridaPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
georgia_tested = georgia1['positive cases'] + georgia1['negative cases']
georgia_population = state_population.iloc[2]['population']
georgia_percentage = (georgia_tested / georgia_population) * 100
georgia_avg = georgia_percentage.mean()

# Set title, axis labels, y-axis limits
plt.bar(georgia1['date'], georgia_percentage, color='blue')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Georgia Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/GeorgiaPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
texas_tested = texas1['positive cases'] + texas1['negative cases']
texas_population = state_population.iloc[5]['population']
texas_percentage = (texas_tested / texas_population) * 100
texas_avg = texas_percentage.mean()

# Set title, axis labels, y-axis limits
plt.bar(texas1['date'], texas_percentage, color='darkorange')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Texas Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/TexasPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
newyork_tested = newyork1['positive cases'] + newyork1['negative cases']
newyork_population = state_population.iloc[4]['population']
newyork_percentage = (newyork_tested / newyork_population) * 100
newyork_avg = newyork_percentage.mean()

# Set title, axis labels, y-axis limits
plt.bar(newyork1['date'], newyork_percentage, color='blueviolet')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('New York Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/NewYorkPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
newjersey_tested = newjersey1['positive cases'] + newjersey1['negative cases']
newjersey_population = state_population.iloc[3]['population']
newjersey_percentage = (newjersey_tested / newjersey_population) * 100
newjersey_avg = newjersey_percentage.mean()

# Set title, axis labels, y-axis limits
plt.bar(newjersey1['date'], newjersey_percentage, color='red')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('New Jersey Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/NewJerseyPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
connecticut_tested = connecticut1['positive cases'] + connecticut1['negative cases']
connecticut_population = state_population.iloc[0]['population']
connecticut_percentage = (connecticut_tested / connecticut_population) * 100
connecticut_avg = connecticut_percentage.mean()

# Set title, axis labels, y-axis limits
plt.bar(connecticut1['date'], connecticut_percentage, color='tan')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Connecticut Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/ConnecticutPercentTested.png')

plt.show()

# %% [markdown]
# We then calculated the correlation coefficient and ran a linear regression to see how closely the average testing percentage of each state correlates to the average daily Covid-19 count.

# %%
# Load the csv file containing daily Covid-19 counts and read as a data frame
dailycount = pd.read_csv('output_data/DailyCount.csv')
dailycount
# Out:
#            State        Date  Daily_Count
# 0    Connecticut  2020-03-08            0
# 1    Connecticut  2020-03-09            0
# 2    Connecticut  2020-03-10            1
# 3    Connecticut  2020-03-11            1
# 4    Connecticut  2020-03-12            3
# ..           ...         ...          ...
# 776        Texas  2020-07-13         5655
# 777        Texas  2020-07-14        10745
# 778        Texas  2020-07-15         7307
# 779        Texas  2020-07-16        10291
# 780        Texas  2020-07-17        14916
#
# [781 rows x 3 columns]

# %%
# Remove the date column as it is unnecessary for this analysis
dailycount.drop(columns=['Date'])

# Average the daily counts per state
dailyaverage = dailycount.groupby('State').mean()['Daily_Count']
dailyaverage
# Out:
# State
# Connecticut     362.818182
# Florida        2406.169118
# Georgia        1106.442623
# New Jersey     1337.462121
# New York       2981.948529
# Texas          2500.065041
# Name: Daily_Count, dtype: float64

# %%
# Create a new data frame that summarizes average daily Covid-19 cases and testing percentages for each state
summarytable = pd.DataFrame({'State': ['Florida', 'Georgia', 'Texas', 'New York', 'New Jersey', 'Connecticut'],
                             'Mean Daily Count': [2406.17, 1106.44, 2500.06, 2981.95, 1337.46, 362.82],
                             'Mean Testing Percentage': [florida_avg, georgia_avg, texas_avg, newyork_avg, newjersey_avg, connecticut_avg]})
summarytable
# Out:
#          State  Mean Daily Count  Mean Testing Percentage
# 0      Florida           2406.17                 4.020862
# 1      Georgia           1106.44                 3.913775
# 2        Texas           2500.06                 3.072513
# 3     New York           2981.95                 8.560078
# 4   New Jersey           1337.46                 6.863831
# 5  Connecticut            362.82                 5.679475

# %%
# Calculate the correlation coefficient
correlation = st.pearsonr(summarytable['Mean Daily Count'], summarytable['Mean Testing Percentage'])
print(f'The correlation coefficient for average daily count and average testing percentage is {round(correlation[0],2)}.')
# Out:
# The correlation coefficient for average daily count and average testing percentage is 0.12.

# %%
# Define the variables for the scatter plot
x_values = summarytable['Mean Testing Percentage']
y_values = summarytable['Mean Daily Count']

# Create a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(5,800),fontsize=15,color="red")

# Label plot
plt.xlabel('Average Testing Percentage')
plt.ylabel('Average Daily Covid-19 Count')

# Print r-squared value
print(f'The r-squared value is: {rvalue**2}')
    
plt.show()
# Out:
# The r-squared value is: 0.01359399414413392

# %% [markdown]
# The correlation coefficient between testing percentages and Covid-19 count was only 0.12, which indicates there is no relationship between the two variables. This is also demonstrated in the scatter plot where the data points are spread all over rather than being clustered in a linear fashion. The r-squared value of 0.0136 indicates that only 1.36% of the movements of daily Covid-19 count (dependent variable) are explained by the movements in the testing percentage (independent variable). Thus, there is no relationship between the two at all.

# %% [markdown]
# ### Third Objective: Did the state shutdown and reopening timings of these six states impact the daily new Covid-19 cases? Did the reopening of specific businesses in certain states cause Covid-19 transmission to skyrocket?
#
# To approach this objective, we manipulated the data from source 1 to show new daily Covid-19 cases rather than total cases. We then created line graphs of date versus new daily counts. We then looked at the line graphs to see if there were any trends and considered these trends against state mandates or reopening phases that were being implemented at the time.

# %%
# Separate each state from the original data frame and create a new column that displays the daily new Covid-19 cases for each state
floridacount = data_1.loc[data_1['state'] == 'Florida']
georgiacount = data_1.loc[data_1['state'] == 'Georgia']
texascount = data_1.loc[data_1['state'] == 'Texas']
newyorkcount = data_1.loc[data_1['state'] == 'New York']
newjerseycount = data_1.loc[data_1['state'] == 'New Jersey']
connecticutcount = data_1.loc[data_1['state'] == 'Connecticut']

# %%
# Subtract the current days total positive cases from next days total positive cases 
floridadaily_count = floridacount['positive cases'].diff()
georgiadaily_count = georgiacount['positive cases'].diff()
texasdaily_count = texascount['positive cases'].diff()
newyorkdaily_count = newyorkcount['positive cases'].diff()
newjerseydaily_count = newjerseycount['positive cases'].diff()
connecticutdaily_count = connecticutcount['positive cases'].diff()

# %%
# Add the new daily count list to each states data frame
floridacount.insert(3, "Daily Count", floridadaily_count, True)
georgiacount.insert(3, "Daily Count", georgiadaily_count, True)
texascount.insert(3, "Daily Count", texasdaily_count, True)
newyorkcount.insert(3, "Daily Count", newyorkdaily_count, True)
newjerseycount.insert(3, "Daily Count", newjerseydaily_count, True)
connecticutcount.insert(3, "Daily Count", connecticutdaily_count, True)

# %%
# Replace any NaN values with zero
floridacount['Daily Count'] = floridacount['Daily Count'].fillna(0)
floridacount['Daily Count'] = floridacount['Daily Count'].astype(int)
floridacount
# Out:
#        state       date  positive cases  Daily Count  negative cases
# 132  Florida 2020-03-04               2            0              24
# 133  Florida 2020-03-05               9            7              31
# 134  Florida 2020-03-06               9            0              55
# 135  Florida 2020-03-07              14            5             100
# 136  Florida 2020-03-08              17            3             118
# ..       ...        ...             ...          ...             ...
# 263  Florida 2020-07-13          282435        12624         2357139
# 264  Florida 2020-07-14          291629         9194         2393614
# 265  Florida 2020-07-15          301810        10181         2434143
# 266  Florida 2020-07-16          315775        13965         2499843
# 267  Florida 2020-07-17          327241        11466         2553527
#
# [136 rows x 5 columns]

# %%
# Replace any NaN values with zero
georgiacount['Daily Count'] = georgiacount['Daily Count'].fillna(0)
georgiacount['Daily Count'] = georgiacount['Daily Count'].astype(int)
georgiacount
# Out:
#        state       date  positive cases  Daily Count  negative cases
# 268  Georgia 2020-03-18             197            0            1311
# 269  Georgia 2020-03-19             287           90            1544
# 270  Georgia 2020-03-20             420          133            1966
# 271  Georgia 2020-03-21             507           87            2557
# 272  Georgia 2020-03-22             600           93            3420
# ..       ...        ...             ...          ...             ...
# 385  Georgia 2020-07-13          120569         3643          987398
# 386  Georgia 2020-07-14          123963         3394         1007071
# 387  Georgia 2020-07-15          127834         3871         1027149
# 388  Georgia 2020-07-16          131275         3441         1046947
# 389  Georgia 2020-07-17          135183         3908         1063495
#
# [122 rows x 5 columns]

# %%
# Replace any NaN values with zero
texascount['Daily Count'] = texascount['Daily Count'].fillna(0)
texascount['Daily Count'] = texascount['Daily Count'].astype(int)
texascount
# Out:
#      state       date  positive cases  Daily Count  negative cases
# 658  Texas 2020-03-17              64            0            1204
# 659  Texas 2020-03-18              83           19            1824
# 660  Texas 2020-03-19             143           60            2212
# 661  Texas 2020-03-20             194           51            5083
# 662  Texas 2020-03-21             304          110            6218
# ..     ...        ...             ...          ...             ...
# 776  Texas 2020-07-13          264313         5655         2275812
# 777  Texas 2020-07-14          275058        10745         2323622
# 778  Texas 2020-07-15          282365         7307         2359834
# 779  Texas 2020-07-16          292656        10291         2407199
# 780  Texas 2020-07-17          307572        14916         2459749
#
# [123 rows x 5 columns]

# %%
# Replace any NaN values with zero
newyorkcount['Daily Count'] = newyorkcount['Daily Count'].fillna(0)
newyorkcount['Daily Count'] = newyorkcount['Daily Count'].astype(int)
newyorkcount
# Out:
#         state       date  positive cases  Daily Count  negative cases
# 522  New York 2020-03-04               6            0              48
# 523  New York 2020-03-05              22           16              76
# 524  New York 2020-03-06              33           11              92
# 525  New York 2020-03-07              76           43              92
# 526  New York 2020-03-08             105           29              92
# ..        ...        ...             ...          ...             ...
# 653  New York 2020-07-13          402263          557         4322619
# 654  New York 2020-07-14          403175          912         4381752
# 655  New York 2020-07-15          404006          831         4444519
# 656  New York 2020-07-16          404775          769         4516435
# 657  New York 2020-07-17          405551          776         4593898
#
# [136 rows x 5 columns]

# %%
# Replace any NaN values with zero
newjerseycount['Daily Count'] = newjerseycount['Daily Count'].fillna(0)
newjerseycount['Daily Count'] = newjerseycount['Daily Count'].astype(int)
newjerseycount
# Out:
#           state       date  positive cases  Daily Count  negative cases
# 390  New Jersey 2020-03-08               6            0              31
# 391  New Jersey 2020-03-09              11            5              35
# 392  New Jersey 2020-03-10              15            4              44
# 393  New Jersey 2020-03-11              24            9              57
# 394  New Jersey 2020-03-12              30            6              74
# ..          ...        ...             ...          ...             ...
# 517  New Jersey 2020-07-13          175522          224         1524863
# 518  New Jersey 2020-07-14          175915          393         1545316
# 519  New Jersey 2020-07-15          176278          363         1566069
# 520  New Jersey 2020-07-16          176501          223         1583403
# 521  New Jersey 2020-07-17          176551           50         1592377
#
# [132 rows x 5 columns]

# %%
# Replace any NaN values with zero
connecticutcount['Daily Count'] = connecticutcount['Daily Count'].fillna(0)
connecticutcount['Daily Count'] = connecticutcount['Daily Count'].astype(int)
connecticutcount
# Out:
#            state       date  positive cases  Daily Count  negative cases
# 0    Connecticut 2020-03-08               1            0              29
# 1    Connecticut 2020-03-09               1            0              46
# 2    Connecticut 2020-03-10               2            1              54
# 3    Connecticut 2020-03-11               3            1              71
# 4    Connecticut 2020-03-12               6            3              89
# ..           ...        ...             ...          ...             ...
# 127  Connecticut 2020-07-13           47510          223          541808
# 128  Connecticut 2020-07-14           47530           20          544231
# 129  Connecticut 2020-07-15           47636          106          556463
# 130  Connecticut 2020-07-16           47750          114          567798
# 131  Connecticut 2020-07-17           47893          143          582076
#
# [132 rows x 5 columns]

# %%
# Plot Covid-19 daily new cases in each state on the same graph for comparison
plt.plot(floridacount['date'], floridacount['Daily Count'], color='green', label='Florida')
plt.plot(georgiacount['date'], georgiacount['Daily Count'], color='blue', label='Georgia')
plt.plot(texascount['date'], texascount['Daily Count'], color='darkorange', label='Texas')
plt.plot(newyorkcount['date'], newyorkcount['Daily Count'], color='blueviolet', label='New York')
plt.plot(newjerseycount['date'], newjerseycount['Daily Count'], color='red', label='New Jersey')
plt.plot(connecticutcount['date'], connecticutcount['Daily Count'], color='tan', label='Connecticut')

# Define labels of plot
plt.title('Covid-19 Daily New Cases')
plt.xlabel('Date')
plt.ylabel('New Cases Per Day')
plt.xticks(rotation=45)
plt.legend(loc='best')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save graph as PNG file
plt.savefig('output_data/CombinedStateDailyCount.png')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# There appears to be two different trends in the states data. Florida, Georgia, and Texas have spikes in daily Covid-19 counts from June onwards, whereas New York, New Jersey, and Connecticut have progressively lower daily counts in the same time frame.
#
# Each states new daily counts was plotted separately and then examined in relation to the state mandates in effect at the time.

# %%
# Plot each state on separate graphs
plt.plot(floridacount['date'], floridacount['Daily Count'], color='green', label='Florida')

# Define labels of plot
plt.title('Florida Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/FloridaDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(georgiacount['date'], georgiacount['Daily Count'], color='blue', label='Georgia')

# Define labels of plot
plt.title('Georgia Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/GeorgiaDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(texascount['date'], texascount['Daily Count'], color='darkorange', label='Texas')

# Define labels of plot
plt.title('Texas Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/TexasDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(newyorkcount['date'], newyorkcount['Daily Count'], color='blueviolet', label='New York')

# Define labels of plot
plt.title('New York Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/NewYorkDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(newjerseycount['date'], newjerseycount['Daily Count'], color='red', label='New Jersey')

# Define labels of plot
plt.title('New Jersey Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/NewJerseyDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(connecticutcount['date'], connecticutcount['Daily Count'], color='tan', label='Connecticut')

# Define labels of plot
plt.title('Connecticut Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/ConnecticutDailyCount.png')

plt.show()

# %% [markdown]
# ### Below, the code creates a new data frame that generated a CSV file for the analysis in our second and third objectives.
#
# Create a new data frame that contains all of the states daily Covid-19 counts for future statistical analysis.

# %%
# Group each states daily count data frames into a list
dfs = [floridacount, georgiacount, texascount, newyorkcount, newjerseycount, connecticutcount]

# %%
# Create an empty data frame with all columns and rows
cols, rows = [], []
for df_i in dfs:
    cols = cols + df_i.columns.tolist()
    rows = rows + df_i.index.tolist()
cols = np.unique(cols)
rows = np.unique(rows)       
df = pd.DataFrame(data=np.NaN, columns=cols, index=rows) 

# Fill the data frame
for df_i in dfs:
    df.loc[df_i.index, df_i.columns] = df_i.values
df
# Out:
#      Daily Count                 date  negative cases  positive cases  \
# 0            0.0  2020-03-08 00:00:00            29.0             1.0
# 1            0.0  2020-03-09 00:00:00            46.0             1.0
# 2            1.0  2020-03-10 00:00:00            54.0             2.0
# 3            1.0  2020-03-11 00:00:00            71.0             3.0
# 4            3.0  2020-03-12 00:00:00            89.0             6.0
# ..           ...                  ...             ...             ...
# 776       5655.0  2020-07-13 00:00:00       2275812.0        264313.0
# 777      10745.0  2020-07-14 00:00:00       2323622.0        275058.0
# 778       7307.0  2020-07-15 00:00:00       2359834.0        282365.0
# 779      10291.0  2020-07-16 00:00:00       2407199.0        292656.0
# 780      14916.0  2020-07-17 00:00:00       2459749.0        307572.0
#
#            state
# 0    Connecticut
# 1    Connecticut
# 2    Connecticut
# 3    Connecticut
# 4    Connecticut
# ...

# %%
# Narrow the data frame to the columns of interest
DailyCount_df = pd.DataFrame({'State': df['state'], 'Date': df['date'], 'Daily_Count': df['Daily Count']})
DailyCount_df
# Out:
#            State                 Date  Daily_Count
# 0    Connecticut  2020-03-08 00:00:00          0.0
# 1    Connecticut  2020-03-09 00:00:00          0.0
# 2    Connecticut  2020-03-10 00:00:00          1.0
# 3    Connecticut  2020-03-11 00:00:00          1.0
# 4    Connecticut  2020-03-12 00:00:00          3.0
# ..           ...                  ...          ...
# 776        Texas  2020-07-13 00:00:00       5655.0
# 777        Texas  2020-07-14 00:00:00      10745.0
# 778        Texas  2020-07-15 00:00:00       7307.0
# 779        Texas  2020-07-16 00:00:00      10291.0
# 780        Texas  2020-07-17 00:00:00      14916.0
#
# [781 rows x 3 columns]

# %%
# Clean up the data frame by removing the time from the dates and changing daily count from float to integer 
DailyCount_df['Date'] = pd.to_datetime(DailyCount_df['Date']).dt.date
DailyCount_df['Daily_Count'] = DailyCount_df['Daily_Count'].astype(int)
DailyCount_df['Daily_Count'].dropna(inplace = True)
DailyCount_df = DailyCount_df.set_index('State')
DailyCount_df
# Out:
#                    Date  Daily_Count
# State
# Connecticut  2020-03-08            0
# Connecticut  2020-03-09            0
# Connecticut  2020-03-10            1
# Connecticut  2020-03-11            1
# Connecticut  2020-03-12            3
# ...                 ...          ...
# Texas        2020-07-13         5655
# Texas        2020-07-14        10745
# Texas        2020-07-15         7307
# Texas        2020-07-16        10291
# Texas        2020-07-17        14916
#
# [781 rows x 2 columns]

# %%
# Save the cleaned up data frame as a new CSV file
DailyCount_df.to_csv('output_data/DailyCount.csv')

# %% [markdown]
# ### Below, the code generates separate line graphs for each state of date versus total confirmed cases. These visuals aided in our presentation.

# %%
# Plot each state on separate graphs
plt.plot(florida1['date'], florida1['positive cases'], color='green', label='Florida')

# Define labels of plot
plt.title('Florida Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Florida.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(georgia1['date'], georgia1['positive cases'], color='blue', label='Georgia')

# Define labels of plot
plt.title('Georgia Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Georgia.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(texas1['date'], texas1['positive cases'], color='darkorange', label='Texas')

# Define labels of plot
plt.title('Texas Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Texas.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(newyork1['date'], newyork1['positive cases'], color='blueviolet', label='New York')

# Define labels of plot
plt.title('New York Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/New_York.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(newjersey1['date'], newjersey1['positive cases'], color='red', label='New Jersey')

# Define labels of plot
plt.title('New Jersey Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/New_Jersey.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(connecticut1['date'], connecticut1['positive cases'], color='tan', label='Connecticut')

# Define labels of plot
plt.title('Connecticut Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Connecticut.png')

plt.show()
