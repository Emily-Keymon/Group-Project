# %% [markdown]
# ## Covid-19 Analysis and Visualizations

# %% [markdown]
# ### Files to work with:
# ##### Source 1 data in output_data/data_source_1
# ##### Source 2 data in output_data/data_source_2
# ##### Source 3 data in output_data/data_source_3
# ##### Population data in output_data/state_pop_df
# ##### State date data in output_data/state_df
#
#
#
# ### First Objective: Determine how the three datasets compare. Are there any consistencies in data? Is there any bias in the data sources?

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import scipy.stats as st
import numpy as np

# Load the csv data files
data_source_1 = 'output_data/data_source_1.csv'
data_source_2 = 'output_data/data_source_2.csv'
data_source_3 = 'output_data/data_source_3.csv'

# Read the Covid-19 data and study the results
data_1 = pd.read_csv(data_source_1)
data_2 = pd.read_csv(data_source_2)
data_3 = pd.read_csv(data_source_3)

# Change the date to data/time format for plotting
data_1['date'] = pd.to_datetime(data_1['date'])
data_2['date'] = pd.to_datetime(data_2['date'])
data_3['date'] = pd.to_datetime(data_3['date'])

print(data_1.dtypes)
# Out:
# state                     object
# date              datetime64[ns]
# positive cases             int64
# negative cases             int64
# dtype: object

# %%
# Preview first data source
data_1
# Out:
#           state       date  positive cases  negative cases
# 0       Florida 2020-03-04               2              24
# 1       Florida 2020-03-05               9              31
# 2       Florida 2020-03-06               9              55
# 3       Florida 2020-03-07              14             100
# 4       Florida 2020-03-08              17             118
# ..          ...        ...             ...             ...
# 651  Washington 2020-07-13           40656          645349
# 652  Washington 2020-07-14           41757          666517
# 653  Washington 2020-07-15           42304          675930
# 654  Washington 2020-07-16           43046          690840
# 655  Washington 2020-07-17           44313          708861
#
# [656 rows x 4 columns]

# %%
# Generate a line plot of date versus positive cases for each of the 5 different states 
florida1 = data_1.loc[data_1['state'] == 'Florida']
georgia1 = data_1.loc[data_1['state'] == 'Georgia']
newyork1 = data_1.loc[data_1['state'] == 'New York']
texas1 = data_1.loc[data_1['state'] == 'Texas']
washington1 = data_1.loc[data_1['state'] == 'Washington']

# Plot each state separately on same graph
plt.plot(florida1['date'], florida1['positive cases'], color='green', label='Florida')
plt.plot(georgia1['date'], georgia1['positive cases'], color='blue', label='Georgia')
plt.plot(newyork1['date'], newyork1['positive cases'], color='blueviolet', label='New York')
plt.plot(texas1['date'], texas1['positive cases'], color='orange', label='Texas')
plt.plot(washington1['date'], washington1['positive cases'], color='red', label='Washington')

# Define labels of plot
plt.title('Data Source 1, Covid-19 Cases for 5 Select States')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.legend(loc="best")

# Save the line plot to a PNG file
plt.savefig('output_data/DataSource1.png')

plt.show()

# %%
# Preview second data source
data_2
# Out:
#           state       date  positive cases
# 0       Florida 2020-03-01               2
# 1       Florida 2020-03-02               2
# 2       Florida 2020-03-03               3
# 3       Florida 2020-03-04               3
# 4       Florida 2020-03-05               4
# ..          ...        ...             ...
# 757  Washington 2020-07-15           45004
# 758  Washington 2020-07-16           46268
# 759  Washington 2020-07-17           47226
# 760  Washington 2020-07-18           47889
# 761  Washington 2020-07-19           48601
#
# [762 rows x 3 columns]

# %%
# Generate a line plot of date versus positive cases for each of the 5 different states 
florida2 = data_2.loc[data_2['state'] == 'Florida']
georgia2 = data_2.loc[data_2['state'] == 'Georgia']
newyork2 = data_2.loc[data_2['state'] == 'New York']
texas2 = data_2.loc[data_2['state'] == 'Texas']
washington2 = data_2.loc[data_2['state'] == 'Washington']

# Plot each state separately on same graph
plt.plot(florida2['date'], florida2['positive cases'], color='green', label='Florida')
plt.plot(georgia2['date'], georgia2['positive cases'], color='blue', label='Georgia')
plt.plot(newyork2['date'], newyork2['positive cases'], color='blueviolet', label='New York')
plt.plot(texas2['date'], texas2['positive cases'], color='orange', label='Texas')
plt.plot(washington2['date'], washington2['positive cases'], color='red', label='Washington')

# Define labels of plot
plt.title('Data Source 2, Covid-19 Cases for 5 Select States')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.legend(loc="best")

# Save the line plot to a PNG file
plt.savefig('output_data/DataSource2.png')

plt.show()

# %%
# Preview the third data source
data_3
# Out:
#           state       date  positive cases
# 0       Florida 2020-03-01               2
# 1       Florida 2020-03-02               2
# 2       Florida 2020-03-03               3
# 3       Florida 2020-03-04               3
# 4       Florida 2020-03-05               4
# ..          ...        ...             ...
# 689  Washington 2020-07-13           43538
# 690  Washington 2020-07-14           44257
# 691  Washington 2020-07-15           45004
# 692  Washington 2020-07-16           46268
# 693  Washington 2020-07-17           47226
#
# [694 rows x 3 columns]

# %%
# Generate a line plot of date versus positive cases for each of the 5 different states 
florida3 = data_3.loc[data_3['state'] == 'Florida']
georgia3 = data_3.loc[data_3['state'] == 'Georgia']
newyork3 = data_3.loc[data_3['state'] == 'New York']
texas3 = data_3.loc[data_3['state'] == 'Texas']
washington3 = data_3.loc[data_3['state'] == 'Washington']

# Plot each state separately on same graph
plt.plot(florida3['date'], florida3['positive cases'], color='green', label='Florida')
plt.plot(georgia3['date'], georgia3['positive cases'], color='blue', label='Georgia')
plt.plot(newyork3['date'], newyork3['positive cases'], color='blueviolet', label='New York')
plt.plot(texas3['date'], texas3['positive cases'], color='orange', label='Texas')
plt.plot(washington3['date'], washington3['positive cases'], color='red', label='Washington')

# Define labels of plot
plt.title('Data Source 3, Covid-19 Cases for 5 Select States')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.legend(loc="best")

# Save the line plot to a PNG file
plt.savefig('output_data/DataSource3.png')

plt.show()

# %% [markdown]
# ### Second Objective: What % of population is tested? How much does testing vary from state to state?

# %%
# Load and read the state population csv file
state_population = pd.read_csv('output_data/state_pop_df.csv')
state_population
# Out:
#         state  population
# 0     Florida    20598139
# 1     Georgia    10297484
# 2    New York    19618453
# 3       Texas    27885195
# 4  Washington     7294336

# %%
# Create bar graph of comparative state population
plt.bar(state_population['state'], state_population['population'], 
        color=['green', 'blue', 'blueviolet', 'orange', 'red'])
plt.title('Comparitive State Population')
plt.xlabel('State')
plt.ylabel('Population (10 mil)')

# Save the bar graph to a PNG file
plt.savefig('output_data/StatePopulation.png')

plt.show()

# %%
# Run calculations for bar graph variables
florida_tested = florida1['positive cases'] + florida1['negative cases']
florida_population = state_population.iloc[0]['population']
florida_percentage = (florida_tested / florida_population) * 100

# Set title, axis labels, y-axis limits 
plt.bar(florida1['date'], florida_percentage, color='green')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Florida Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/FloridaPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
georgia_tested = georgia1['positive cases'] + georgia1['negative cases']
georgia_population = state_population.iloc[1]['population']
georgia_percentage = (georgia_tested / georgia_population) * 100

# Set title, axis labels, y-axis limits
plt.bar(georgia1['date'], georgia_percentage, color='blue')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Georgia Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/GeorgiaPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
newyork_tested = newyork1['positive cases'] + newyork1['negative cases']
newyork_population = state_population.iloc[2]['population']
newyork_percentage = (newyork_tested / newyork_population) * 100

# Set title, axis labels, y-axis limits
plt.bar(newyork1['date'], newyork_percentage, color='blueviolet')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('New York Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/NewYorkPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
texas_tested = texas1['positive cases'] + texas1['negative cases']
texas_population = state_population.iloc[3]['population']
texas_percentage = (texas_tested / texas_population) * 100

# Set title, axis labels, y-axis limits
plt.bar(texas1['date'], texas_percentage, color='orange')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Texas Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/TexasPercentTested.png')

plt.show()

# %%
# Run calculations for bar graph variables
washington_tested = washington1['positive cases'] + washington1['negative cases']
washington_population = state_population.iloc[4]['population']
washington_percentage = (washington_tested / washington_population) * 100

# Set title, axis labels, y-axis limits
plt.bar(washington1['date'], washington_percentage, color='red')
plt.xticks(rotation=45)
plt.ylim(0, 28, 5)
plt.title('Washington Percentage of Population Being Tested')
plt.xlabel('Date')
plt.ylabel('Percent Tested (%)')

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the bar graph to a PNG file
plt.savefig('output_data/WashingtonPercentTested.png')

plt.show()

# %% [markdown]
# ### Third Objective: Was there any impact from the state shutdown and reopening timing on these five states?

# %%
# Creat a new column in the data frame that displays the daily Covid-19 count for each state
data_1

floridacount = data_1.loc[data_1['state'] == 'Florida']
georgiacount = data_1.loc[data_1['state'] == 'Georgia']
newyorkcount = data_1.loc[data_1['state'] == 'New York']
texascount = data_1.loc[data_1['state'] == 'Texas']
washingtoncount = data_1.loc[data_1['state'] == 'Washington']

# %%
# Subtract the current days total positive cases from next days total positive cases 
floridadaily_count = floridacount['positive cases'].diff()
georgiadaily_count = georgiacount['positive cases'].diff()
newyorkdaily_count = newyorkcount['positive cases'].diff()
texasdaily_count = texascount['positive cases'].diff()
washingtondaily_count = washingtoncount['positive cases'].diff()

# %%
# Add the new daily count list to each states data frame
floridacount.insert(3, "Daily Count", floridadaily_count, True)
georgiacount.insert(3, "Daily Count", georgiadaily_count, True)
newyorkcount.insert(3, "Daily Count", newyorkdaily_count, True)
texascount.insert(3, "Daily Count", texasdaily_count, True)
washingtoncount.insert(3, "Daily Count", washingtondaily_count, True)

# %%
# Replace any NaN values with zero
floridacount['Daily Count'] = floridacount['Daily Count'].fillna(0)
floridacount['Daily Count'] = floridacount['Daily Count'].astype(int)
floridacount
# Out:
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        state       date  positive cases  Daily Count  negative cases
# 0    Florida 2020-03-04               2            0              24
# 1    Florida 2020-03-05               9            7              31
# 2    Florida 2020-03-06               9            0              55
# 3    Florida 2020-03-07              14            5             100
# 4    Florida 2020-03-08              17            3             118
# ..       ...        ...             ...          ...             ...
# 131  Florida 2020-07-13          282435        12624         2357139
# 132  Florida 2020-07-14          291629         9194         2393614
# 133  Florida 2020-07-15          301810        10181         2434143
# 134  Florida 2020-07-16          315775        13965         2499843
# 135  Florida 2020-07-17          327241        11466         2553527
#
# [136 rows x 5 columns]

# %%
# Replace any NaN values with zero
georgiacount['Daily Count'] = georgiacount['Daily Count'].fillna(0)
georgiacount['Daily Count'] = georgiacount['Daily Count'].astype(int)
georgiacount
# Out:
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        state       date  positive cases  Daily Count  negative cases
# 136  Georgia 2020-03-18             197            0            1311
# 137  Georgia 2020-03-19             287           90            1544
# 138  Georgia 2020-03-20             420          133            1966
# 139  Georgia 2020-03-21             507           87            2557
# 140  Georgia 2020-03-22             600           93            3420
# ..       ...        ...             ...          ...             ...
# 253  Georgia 2020-07-13          120569         3643          987398
# 254  Georgia 2020-07-14          123963         3394         1007071
# 255  Georgia 2020-07-15          127834         3871         1027149
# 256  Georgia 2020-07-16          131275         3441         1046947
# 257  Georgia 2020-07-17          135183         3908         1063495
#
# [122 rows x 5 columns]

# %%
# Replace any NaN values with zero
newyorkcount['Daily Count'] = newyorkcount['Daily Count'].fillna(0)
newyorkcount['Daily Count'] = newyorkcount['Daily Count'].astype(int)
newyorkcount
# Out:
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         state       date  positive cases  Daily Count  negative cases
# 258  New York 2020-03-04               6            0              48
# 259  New York 2020-03-05              22           16              76
# 260  New York 2020-03-06              33           11              92
# 261  New York 2020-03-07              76           43              92
# 262  New York 2020-03-08             105           29              92
# ..        ...        ...             ...          ...             ...
# 389  New York 2020-07-13          402263          557         4322619
# 390  New York 2020-07-14          403175          912         4381752
# 391  New York 2020-07-15          404006          831         4444519
# 392  New York 2020-07-16          404775          769         4516435
# 393  New York 2020-07-17          405551          776         4593898
#
# [136 rows x 5 columns]

# %%
# Replace any NaN values with zero
texascount['Daily Count'] = texascount['Daily Count'].fillna(0)
texascount['Daily Count'] = texascount['Daily Count'].astype(int)
texascount
# Out:
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      state       date  positive cases  Daily Count  negative cases
# 394  Texas 2020-03-17              64            0            1204
# 395  Texas 2020-03-18              83           19            1824
# 396  Texas 2020-03-19             143           60            2212
# 397  Texas 2020-03-20             194           51            5083
# 398  Texas 2020-03-21             304          110            6218
# ..     ...        ...             ...          ...             ...
# 512  Texas 2020-07-13          264313         5655         2275812
# 513  Texas 2020-07-14          275058        10745         2323622
# 514  Texas 2020-07-15          282365         7307         2359834
# 515  Texas 2020-07-16          292656        10291         2407199
# 516  Texas 2020-07-17          307572        14916         2459749
#
# [123 rows x 5 columns]

# %%
# Replace any NaN values with zero
washingtoncount['Daily Count'] = washingtoncount['Daily Count'].fillna(0)
washingtoncount['Daily Count'] = washingtoncount['Daily Count'].astype(int)
washingtoncount
# Out:
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/kiranrangaraj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           state       date  positive cases  Daily Count  negative cases
# 517  Washington 2020-03-01             377            0              12
# 518  Washington 2020-03-02             450           73             123
# 519  Washington 2020-03-03             534           84             264
# 520  Washington 2020-03-04             626           92             417
# 521  Washington 2020-03-05             731          105             672
# ..          ...        ...             ...          ...             ...
# 651  Washington 2020-07-13           40656         1438          645349
# 652  Washington 2020-07-14           41757         1101          666517
# 653  Washington 2020-07-15           42304          547          675930
# 654  Washington 2020-07-16           43046          742          690840
# 655  Washington 2020-07-17           44313         1267          708861
#
# [139 rows x 5 columns]

# %%
# Plot each state on separate graphs
plt.plot(floridacount['date'], floridacount['Daily Count'], color='green', label='Florida')

# Define labels of plot
plt.title('Florida Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/FloridaDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(georgiacount['date'], georgiacount['Daily Count'], color='blue', label='Georgia')

# Define labels of plot
plt.title('Georgia Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/GeorgiaDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(newyorkcount['date'], newyorkcount['Daily Count'], color='blueviolet', label='New York')

# Define labels of plot
plt.title('New York Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/NewYorkDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(texascount['date'], texascount['Daily Count'], color='orange', label='Texas')

# Define labels of plot
plt.title('Texas Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/TexasDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(washingtoncount['date'], washingtoncount['Daily Count'], color='red', label='Washington')

# Define labels of plot
plt.title('Washington Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/WashingtonDailyCount.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(florida1['date'], florida1['positive cases'], color='green', label='Florida')

# Define labels of plot
plt.title('Florida Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Florida.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(georgia1['date'], georgia1['positive cases'], color='blue', label='Georgia')

# Define labels of plot
plt.title('Georgia Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Georgia.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(newyork1['date'], newyork1['positive cases'], color='blueviolet', label='New York')

# Define labels of plot
plt.title('New York Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/New_York.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(texas1['date'], texas1['positive cases'], color='orange', label='Texas')

# Define labels of plot
plt.title('Texas Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Texas.png')

plt.show()

# %%
# Plot each state on separate graphs
plt.plot(washington1['date'], washington1['positive cases'], color='red', label='Washington')

# Define labels of plot
plt.title('Washington Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('Total Positive Cases (Per Day)')
plt.xticks(rotation=45)

# Set x-axis ticks to month & year
locator = mdates.MonthLocator()
plt.gca().xaxis.set_major_locator(locator)
plt.gcf().autofmt_xdate()

# Save the line plot to a PNG file
plt.savefig('output_data/Washington.png')

plt.show()
